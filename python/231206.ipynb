# %% [markdown]
# # 외부 라이브러리

# %%
pip list
# Out:
# Active code page: 65001
# Package                           Version
# --------------------------------- ---------
# absl-py                           1.4.0
# aiohttp                           3.8.5
# aiosignal                         1.2.0
# anyio                             3.5.0
# appdirs                           1.4.4
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arviz                             0.11.2
# astor                             0.8.1
# asttokens                         2.0.5
# astunparse                        1.6.3
# async-timeout                     4.0.2
# attrs                             22.1.0
# azure-core                        1.29.3
# azure-identity                    1.14.0
# azure-storage-blob                12.17.0
# Babel                             2.11.0
# backcall                          0.2.0
# beautifulsoup4                    4.11.1
# bleach                            4.1.0
# ...

# %%
pip --version
# Out:
# Active code page: 65001
# pip 23.2.1 from C:\Users\Jiyoung\miniconda3\envs\ds_study\lib\site-packages\pip (python 3.8)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list
# Out:
# Active code page: 65001
# # packages in environment at C:\Users\Jiyoung\miniconda3\envs\ds_study:
# #
# # Name                    Version                   Build  Channel
# _tflow_select             2.3.0                       mkl
# abseil-cpp                20211102.0           hd77b12b_0
# absl-py                   1.4.0            py38haa95532_0
# aiohttp                   3.8.5            py38h2bbff1b_0
# aiosignal                 1.2.0              pyhd3eb1b0_0
# anyio                     3.5.0            py38haa95532_0
# appdirs                   1.4.4              pyhd3eb1b0_0
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py38h2bbff1b_0
# arviz                     0.11.2             pyhd3eb1b0_0
# astor                     0.8.1            py38haa95532_0
# asttokens                 2.0.5              pyhd3eb1b0_0
# astunparse                1.6.3                      py_0
# ...

# %%
pip install Faker
# Out:
# Active code page: 65001
# ...
#   Obtaining dependency information for Faker from https://files.pythonhosted.org/packages/cc/9a/74db0cf3115df2f71edcaf8d86ed556195ac31575212c20425820f81bfd0/Faker-20.1.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.7 MB 660.6 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.7 MB 3.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.7 MB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 1.2/1.7 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 7.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from faker import Faker
fake = Faker()
fake.name()
# Out:
# 'Patricia Johnson'

# %%
fake = Faker('ko-KR')
fake.name()
# Out:
# '손민지'

# %%
fake.address()
# Out:
# '강원도 성남시 분당구 삼성1로 (혜진정홍면)'

# %%
test_data = [(fake.name(), fake.address()) for i in range(30)]

# %%
test_data
# Faker documents 검색해서 참고하기~
# Out:
# [('박성현', '경기도 시흥시 서초중앙로'),
#  ('김옥자', '경기도 증평군 잠실로'),
#  ('차현정', '광주광역시 서초구 영동대거리 (지원엄김면)'),
#  ('배정웅', '광주광역시 서대문구 학동776길'),
#  ('심준호', '대전광역시 강동구 오금로'),
#  ('이은지', '전라남도 수원시 압구정로'),
#  ('허예진', '세종특별자치시 남구 석촌호수로 (영환김마을)'),
#  ('성민수', '강원도 수원시 팔달구 반포대가 (유진이읍)'),
#  ('김영수', '대전광역시 서초구 역삼거리 (미숙심리)'),
#  ('강승민', '전라남도 제천시 역삼가'),
#  ('이보람', '서울특별시 북구 오금02로'),
#  ('윤지연', '울산광역시 동구 석촌호수거리'),
#  ('김은정', '경상남도 진천군 서초중앙7가'),
#  ('조준혁', '강원도 속초시 테헤란407가'),
#  ('김옥순', '울산광역시 강동구 개포62로'),
#  ('이영식', '인천광역시 서구 테헤란거리 (정자김윤읍)'),
#  ('양재현', '제주특별자치도 진천군 오금길'),
#  ('이예진', '충청북도 단양군 서초대219가'),
#  ('신영자', '세종특별자치시 서구 석촌호수거리 (영미김강면)'),
#  ('박광수', '대구광역시 강북구 삼성19거리'),
#  ('최상호', '충청남도 화천군 오금길 (은주김한동)'),
#  ('김영식', '대전광역시 서구 압구정843로 (주원김읍)'),
#  ('우재현', '전라남도 양구군 압구정길 (현주임읍)'),
#  ('남서윤', '광주광역시 마포구 서초대길 (서윤이마을)'),
#  ('김정식', '인천광역시 성동구 영동대거리 (준서박면)'),
#  ('허병철', '충청남도 가평군 잠실218길'),
#  ('장정남', '광주광역시 서대문구 서초중앙569길'),
#  ('서도윤', '충청남도 화천군 서초중앙가 (은주이박읍)'),
#  ('김성진', '제주특별자치도 의왕시 도산대54길'),
# ...
